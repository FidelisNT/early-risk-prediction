# %%
import pandas as pd

print("Heart")
print(pd.read_csv("../datasets/heart.csv").columns.tolist())

print("\nDiabetes")
print(pd.read_csv("../datasets/diabetes.csv").columns.tolist())

print("\nKidney")
print(pd.read_csv("../datasets/kidney.csv").columns.tolist())

print("\nStroke")
print(pd.read_csv("../datasets/stroke.csv").columns.tolist())
# Out:
# Heart
# ['Age', 'Sex', 'Cp', 'Trestbps', 'Chol', 'Fbs', 'Restecg', 'Thalach', 'Exang', 'Oldpeak', 'Slope', 'Ca', 'Thal', 'Num', 'TargetBinary']
#
# Diabetes
# ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']
#
# Kidney
# ['Bp', 'Sg', 'Al', 'Su', 'Rbc', 'Bu', 'Sc', 'Sod', 'Pot', 'Hemo', 'Wbcc', 'Rbcc', 'Htn', 'Class']
#
# Stroke
# ['Id', 'Gender', 'Age', 'Hypertension', 'HeartDisease', 'EverMarried', 'WorkType', 'ResidenceType', 'AvgGlucoseLevel', 'Bmi', 'SmokingStatus', 'Stroke']
